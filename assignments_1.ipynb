# %% [markdown]
# $$
# x^3 + 5x - \pi x^3 + \log_{2}(e^x) + \sin(x) + \sin^{-1}\!\left(\frac{x}{10}\right) + \frac{e^x}{e^{x+1}} + \log_{10}(|x^3| + 1) + \pi x^4 + \sinh(x^3) + \ln\!\left(|\sin(\cosh(x))| + 1\right)
# $$

# %%
import math
x =  0.1
expression =  (
    ((math.log2(x**3))**(1/3))**(1/5)
    + (math.exp(x))**2
    + (x*math.log(x))**(1/16)
    + (math.sinh(x))**(1/2)
    + math.cos(x**3 + 8)
    + ((math.pi)**1/2)**(8/9)
    + math.sin((x**2 + 1)**(1/2))
    + (math.atan(x**3 - math.pi**2 + 8*x))**9
)

print(expression)
# Out:
# (-24.558438464521455+0.4203330827228041j)

# %% [markdown]
# $$
# v(x)=\frac{e^{\sin(x)}+e^{\cos(x)}}{2}
# +\ln(\sin(x)+\cos(x))
# +\sqrt{\tan^2(x)+1}
# +\sinh^{-1}(x)
# -\cosh\left(\frac{x}{2}\right)
# +\frac{\pi x^2}{e}
# +\sec^2(x)
# -\tan^2(x)
# $$

# %%
import math
x = math.pi / 3

output = (((math.exp(math.sin(x)) + math.exp(math.cos(x))) / 2)
          + math.log(math.sin(x) + math.cos(x))
          + (1/math.cos(x))
          + math.log(x+(x**2 + 1)**(1/2))
          - math.cosh(x/2)
          + (math.pi * x**2)/math.exp(1)
          +1
          
          

)

print(output)
# Out:
# 6.366502525239908

# %% [markdown]
# $$
# f(x)=\pi x^3+\log(x)+\sqrt{x^3}+\tan(x)+e^x
# $$

# %%
import math
x = 3

expression = (
    math.pi * x**3
    + math.log(x)
    + (x**3)**(1/2)
    + math.tan(x) 
    + math.exp(x)
)

print(expression)
# Out:
# 111.06075673841255

# %% [markdown]
# $$
# g(x)=\frac{e^{2x}+\cosh(x)}{\sinh(x)+\log_{10}(x)}
# +\sqrt[3]{x^5}
# -\tan^{-1}(x)
# $$

# %%
import math 
x = 2

expression = (
    (math.exp(2*x) + math.cosh(x)) / (math.sinh(x) + math.log10(x))
    + (x**5)**(1/3)
    - math.atan(x)
)
print(expression)
# Out:
# 16.92558976646027

# %% [markdown]
# $$
# h(x)=\sin(2x)\cdot\cos(x)
# +\frac{\tan(x)}{\cot(x)}
# +e^{\sin(x)}
# +\ln(\cos(x))
# +x^{\pi}
# $$

# %%
import math
x = math.pi/4

expression = (
    math.sin(2*x) * math.cos(x)
    + math.tan(x)**2
    + math.exp(math.sin(x))
    + math.log(math.cos(x))
    + x**math.pi
)
print(expression)
# Out:
# 3.8568306355372277

# %% [markdown]
# $$
# p(x)=\sqrt{e^x+\sinh(2x)}
# +\frac{\ln(x^2+1)}{\tanh(x)}
# +x^x
# -\cos^{-1}\left(\frac{x}{2}\right)
# +\cosh^2(x)
# $$

# %%
import math
x = 1.5

expression = (
    
    (math.exp(x) + math.sinh(2*x)) ** (1/2)
    + math.log(x**2 + 1) / math.tanh(x)
    +x**x 
    - math.acos(x/2)
    + (math.cosh(x))**2
)

print(expression)
# Out:
# 11.758211255018086

# %% [markdown]
# $$
# q(x) =
# \frac{\pi x \cdot e^{2x}}{\sqrt{\sinh(x) + \cosh(x)}}
# + \log_{2}(x+1)\cdot \tan\!\left(\frac{\pi x}{6}\right)
# + \sqrt[4]{x^7}
# - \sin^{-1}(x)
# $$

# %%
x = 0.5

expression = (
    ((math.pi**x) * (math.exp(x*2)))/((math.exp(x))**(1/2))
    + math.log2(x+1) * math.tan((math.pi * x)/6)
    + (x**7)**(1/4)
    - math.asin(x)
)

print(expression)
# Out:
# 3.682728064635281

# %% [markdown]
# $$
# r(x) =
# \left(e^x + e^{-x}\right)^2
# - 4\sinh^2(x)
# + \frac{\ln(x)}{\sqrt{x}}
# + \cos(x)\sec(x)
# + \tanh^{-1}\!\left(\frac{x-2}{x}\right)
# $$

# %%
x = 2.5

expression = (
    (math.exp(x) + (1 / math.exp(x)))**2
    - 4 * (math.sinh(x))**2
    + (x * math.log(x) - x)/ x**(1/2)
    + 1
    + math.atanh((x-2)/x)
)

print(expression)
# Out:
# 5.0703765797823515

# %% [markdown]
# $$
# t(x) =
# \sqrt[3]{e^{3x} + \pi^x}
# + \frac{\cosh(2x) - 1}{\sinh^2(x)}
# + \ln\!\left(\tan\!\left(\frac{\pi}{4} + \frac{x}{2}\right)\right)
# + x^\pi
# - \cos^{-1}\!\left(\frac{1}{e}\right)
# $$

# %%
x = 1

expression =(
    (math.exp(3*x) + math.pi**x)**(1/3)
    + (2*(math.sinh(x))**2)/ (math.sinh(x)**2)
    + math.log(math.tan((math.pi/4)+ (x/2)))
    + x**math.pi
    - math.acos(1/math.exp(1))
)

print(expression)
# Out:
# 5.8853199359882105

# %% [markdown]
# $$
# s(x) =
# \frac{\sin^3(x) + \cos^3(x)}{\sin(x) + \cos(x)}
# + e^{\tan(x)}
# - \ln\!\left(\frac{1}{\csc(x)}\right)
# + \sinh(x).csch(x)
# + \sqrt{\pi x^2}
# $$

# %%
x = math.pi/6

expression = (
    (math.sin(x)**3  + math.cos(x)**3) / (math.sin(x) + math.cos(x))
    + math.exp(math.tan(x))
    - math.log(math.sin(x))
    + math.sinh(x)* (1/math.sinh(x))
    + (math.pi * x**2)**(1/2)

)
print(expression)
# Out:
# 4.969501318917146

# %% [markdown]
# $$
# u(x) =
# e^{x^2}\sin(\pi x)
# + \frac{\ln(1+x^2)}{\tanh(2x)}
# + \sqrt{\cosh^2(x) - \sinh^2(x)}
# + \tan^{-1}(e^x)
# - \frac{\pi^2 x}{e^x}
# $$

# %%
x = 0.8

expression = (
    math.exp(x**2) * math.sin(math.pi * x)
    + math.log(1+x**2) / math.tanh(2 * x)

    + 1
    + math.atan(math.exp(x))
    - math.pi**2 *x / math.exp(x)

)
print(expression)
# Out:
# 0.2522046196584946
